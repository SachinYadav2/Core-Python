# %% [markdown]
# ## Jab tak ke hmari while ke condtiosn True h tab tak ye while loop me rhega Other Wise Rest of the code Execute hoga

# %%
# Try Run se ham check krte h logic ko always ,   Copy pen se
a = 1
while(5>a):
    print("Five is Greater",a)
    a = a+1 # Increment Concept Lagana pdta h other wise YOur Code is Infinite loop me fus jaega 
    
print("Rest OF the Code")
# Out:
# Five is Greater 1
# Five is Greater 2
# Five is Greater 3
# Five is Greater 4
# Rest OF the Code

# %% [markdown]
# ## While with else Hamara else Ek bar Always Execute hoga Reason is very Simple
# - https://www.pythontutorial.net/wp-content/uploads/2020/10/Python-while-else.png

# %%
a = 1
while (a<=5):
    print(a)
    a+=1
else:
    print("ye while ke False ke con me or true ke condtion me Dono me run hota")
# Out:
# 1
# 2
# 3
# 4
# 5
# ye while ke False ke con me or true ke condtion me Dono me run hota

# %%
a = 6
while (a<=5):
    print(a)
    a+=1
else:
    print("ye while ke False ke con me or true ke condtion me Dono me run hota because  ek bar loop me condi.. False hoti h h")
# Out:
# ye while ke False ke con me or true ke condtion me Dono me run hota because  ek bar loop me condi.. False hoti h h

# %% [markdown]
# ## Concept of Loop

# %%
a = 4
while (a<=5):
    print("Phle ke ",a)

    a+=1
    print("Bad ke ",a)
else:
    print("ye while ke False ke con me or true ke condtion me Dono me run hota because  ek bar loop me condi.. False hoti h h")

# %% [markdown]
# ## While Infinite

# %%
while(True):
    print("Always Run ho Rha h")
else:
    print("Es Condtions ME ye Code Execute nhi hoaga")
print("Rest Of the not Execute in this type of condi")
# Out:
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# Always Run ho Rha h
# ...

# %%
i = 0
while(True):
    i+=1
    print(i)
    if (i==3):
        break
print("Rest Of the Code:")
# Out:
# 1
# 2
# 3
# Rest Of the Code:

# %% [markdown]
# ## Nested while Loop

# %%
i = 1
while i<=2:
    print("Outer Loop:")
    i+=1
    j = 1
    while j<=5:
        print("Inner LOop:")
        j+=1
print("Rest of the code:")
# Out:
# Outer Loop:
# Inner LOop:
# Inner LOop:
# Inner LOop:
# Inner LOop:
# Inner LOop:
# Outer Loop:
# Inner LOop:
# Inner LOop:
# Inner LOop:
# Inner LOop:
# Inner LOop:
# Rest of the code:

# %%
range()
